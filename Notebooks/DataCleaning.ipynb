# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <center> Read CSV file</center>

# %%
# NEED TO CHANGE TO SPECIFIED LOC 
# df = pd.read_csv(r"output.csv", low_memory=False)
df.head()
# Out:
#           Study ID Patient ID Sample ID  Acquisition Method Type  \
# 0  coad_cptac_2019    01CO001   01CO001                      NaN
# 1  coad_cptac_2019    01CO005   01CO005                      NaN
# 2  coad_cptac_2019    01CO006   01CO006                      NaN
# 3  coad_cptac_2019    01CO008   01CO008                      NaN
# 4  coad_cptac_2019    01CO013   01CO013                      NaN
#
#   Adjuvant Chemotherapy Adjuvant Treatment  Advanced  Diagnosis Age  \
# 0                   NaN                NaN       NaN           61.0
# 1                   NaN                NaN       NaN           70.0
# 2                   NaN                NaN       NaN           75.0
# 3                   NaN                NaN       NaN           54.0
# 4                   NaN                NaN       NaN           58.0
#
#    Age at derivation  Age at Diagnosis  ...  UVA Signature  \
# 0                NaN               NaN  ...            NaN
# 1                NaN               NaN  ...            NaN
# 2                NaN               NaN  ...            NaN
# 3                NaN               NaN  ...            NaN
# 4                NaN               NaN  ...            NaN
#
#    Vascular invasion indicator Vessel Invasion  Vial number  \
# 0                          NaN             NaN          NaN
# 1                          NaN             NaN          NaN
# 2                          NaN             NaN          NaN
# 3                          NaN             NaN          NaN
# 4                          NaN             NaN          NaN
#
#    Patient's Vital Status  Vital Status Code Patient Weight  WGD  \
# 0                     NaN                NaN            NaN  NaN
# 1                     NaN                NaN            NaN  NaN
# 2                     NaN                NaN            NaN  NaN
# 3                     NaN                NaN            NaN  NaN
# 4                     NaN                NaN            NaN  NaN
#
#   Winter Hypoxia Score Year of Diagnosis
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
#
# [5 rows x 463 columns]

# %%
df.loc[:, df.columns.str.lower().str.contains("age")].head()
# Out:
#    Diagnosis Age  Age at derivation  Age at Diagnosis  Age At Diagnosis  \
# 0           61.0                NaN               NaN               NaN
# 1           70.0                NaN               NaN               NaN
# 2           75.0                NaN               NaN               NaN
# 3           54.0                NaN               NaN               NaN
# 4           58.0                NaN               NaN               NaN
#
#    Age at Metastases Age at Sequencing  \
# 0                NaN               NaN
# 1                NaN               NaN
# 2                NaN               NaN
# 3                NaN               NaN
# 4                NaN               NaN
#
#    Age at Which Sequencing was Reported (Days)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Age at Which Sequencing was Reported (Years)  Age at Diagnosis.1  \
# 0                                           NaN                 NaN
# 1                                           NaN                 NaN
# 2                                           NaN                 NaN
# 3                                           NaN                 NaN
# 4                                           NaN                 NaN
#
#   Age Groups  ... Stage.1 Stage At Diagnosis Stage at Diagnosis Stage_Dx  \
# 0        NaN  ...     NaN                NaN                NaN      NaN
# 1        NaN  ...     NaN                NaN                NaN      NaN
# 2        NaN  ...     NaN                NaN                NaN      NaN
# 3        NaN  ...     NaN                NaN                NaN      NaN
# 4        NaN  ...     NaN                NaN                NaN      NaN
#
#    Stage Other Storage Method  TNM Stage  TNM Stage at Diagnosis  Tumor Stage  \
# 0          NaN            NaN        NaN                     NaN          NaN
# 1          NaN            NaN        NaN                     NaN          NaN
# 2          NaN            NaN        NaN                     NaN          NaN
# 3          NaN            NaN        NaN                     NaN          NaN
# 4          NaN            NaN        NaN                     NaN          NaN
#
#   Tumor Stage 2009
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# <center> Find columns that contain diagnosis age (or similar) and combine. Choose first non-null age.</center>

# %% [markdown]
# REF https://shecancode.io/filter-a-pandas-dataframe-by-a-partial-string-or-pattern-in-8-ways/#:~:text=Filter%20rows%20that%20match%20a%20given%20String%20in%20a%20column&text=We%20will%20use%20the%20Series,in%20the%20isin()%20function.

# %%
mask = (df.columns.str.lower().str.contains("age") 
        & df.columns.str.lower().str.contains("diagnos")
        & ~df.columns.str.lower().str.contains("stage")
       )

df.loc[:,mask].head()
cols = df.columns[mask]
# Not sure if bfill is the best choice here
df["Diagnosis Age"] = df.loc[:,cols].bfill(axis = 1).iloc[:,0]
df.drop(columns=cols).copy()
df.head()
# Out:
#           Study ID Patient ID Sample ID  Acquisition Method Type  \
# 0  coad_cptac_2019    01CO001   01CO001                      NaN
# 1  coad_cptac_2019    01CO005   01CO005                      NaN
# 2  coad_cptac_2019    01CO006   01CO006                      NaN
# 3  coad_cptac_2019    01CO008   01CO008                      NaN
# 4  coad_cptac_2019    01CO013   01CO013                      NaN
#
#   Adjuvant Chemotherapy Adjuvant Treatment  Advanced  Diagnosis Age  \
# 0                   NaN                NaN       NaN           61.0
# 1                   NaN                NaN       NaN           70.0
# 2                   NaN                NaN       NaN           75.0
# 3                   NaN                NaN       NaN           54.0
# 4                   NaN                NaN       NaN           58.0
#
#    Age at derivation  Age at Diagnosis  ...  UVA Signature  \
# 0                NaN               NaN  ...            NaN
# 1                NaN               NaN  ...            NaN
# 2                NaN               NaN  ...            NaN
# 3                NaN               NaN  ...            NaN
# 4                NaN               NaN  ...            NaN
#
#    Vascular invasion indicator Vessel Invasion  Vial number  \
# 0                          NaN             NaN          NaN
# 1                          NaN             NaN          NaN
# 2                          NaN             NaN          NaN
# 3                          NaN             NaN          NaN
# 4                          NaN             NaN          NaN
#
#    Patient's Vital Status  Vital Status Code Patient Weight  WGD  \
# 0                     NaN                NaN            NaN  NaN
# 1                     NaN                NaN            NaN  NaN
# 2                     NaN                NaN            NaN  NaN
# 3                     NaN                NaN            NaN  NaN
# 4                     NaN                NaN            NaN  NaN
#
#   Winter Hypoxia Score Year of Diagnosis
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
#
# [5 rows x 463 columns]

# %% [markdown]
# <center>Should we do something with Year of Diagnosis?

# %% [markdown]
# <center>Create new Dataframe only with essential information</center>

# %%
for col in df.columns:
    df.columns = df.columns.str.strip()

# %%
rel_df = df[["Study ID", "Sample ID", "Diagnosis Age"]]
rel_df.head()
# Out:
#           Study ID Sample ID  Diagnosis Age
# 0  coad_cptac_2019   01CO001           61.0
# 1  coad_cptac_2019   01CO005           70.0
# 2  coad_cptac_2019   01CO006           75.0
# 3  coad_cptac_2019   01CO008           54.0
# 4  coad_cptac_2019   01CO013           58.0

# %% [markdown]
# <center>Remove entries with no diagnosis age attached</center>

# %%
removed_rows = rel_df.dropna(subset =["Diagnosis Age"], axis = 0)
removed_rows.head()
# Out:
#           Study ID Sample ID  Diagnosis Age
# 0  coad_cptac_2019   01CO001           61.0
# 1  coad_cptac_2019   01CO005           70.0
# 2  coad_cptac_2019   01CO006           75.0
# 3  coad_cptac_2019   01CO008           54.0
# 4  coad_cptac_2019   01CO013           58.0

# %% [markdown]
# <center> Remove duplicate samples</center>

# %%
print(removed_rows.shape)
# Out:
# (6499, 3)

# %%
unique_samples = removed_rows["Sample ID"].unique()
print(unique_samples.shape)
# Out:
# (4946,)

# %%
cleaned_df = removed_rows.drop_duplicates(subset=["Sample ID"], keep='first')
cleaned_df.shape
# Out:
# (4946, 3)

# %%
cleaned_df.head()
# Out:
#           Study ID Sample ID  Diagnosis Age
# 0  coad_cptac_2019   01CO001           61.0
# 1  coad_cptac_2019   01CO005           70.0
# 2  coad_cptac_2019   01CO006           75.0
# 3  coad_cptac_2019   01CO008           54.0
# 4  coad_cptac_2019   01CO013           58.0

# %% [markdown]
# <center> Add column for early onset</center>

# %%
cleaned_df = cleaned_df.copy()
cleaned_df["Early Onset"] = cleaned_df["Diagnosis Age"] <= 40
cleaned_df.head()
# Out:
#           Study ID Sample ID  Diagnosis Age  Early Onset
# 0  coad_cptac_2019   01CO001           61.0        False
# 1  coad_cptac_2019   01CO005           70.0        False
# 2  coad_cptac_2019   01CO006           75.0        False
# 3  coad_cptac_2019   01CO008           54.0        False
# 4  coad_cptac_2019   01CO013           58.0        False

# %% [markdown]
# <center> Locate rows where Early Onset = True</center>

# %%
early_onset = cleaned_df.copy()
early_onset.loc[early_onset["Early Onset"] == True]
# Out:
#                Study ID       Sample ID  Diagnosis Age  Early Onset
# 11      coad_cptac_2019         05CO004           40.0         True
# 15      coad_cptac_2019         05CO011           39.0         True
# 64      coad_cptac_2019         11CO036           37.0         True
# 83      coad_cptac_2019         11CO070           35.0         True
# 185      crc_orion_2024             C10           25.0         True
# ...                 ...             ...            ...          ...
# 7849  crc_nigerian_2020  s_PK_crc_121_T           28.0         True
# 7853  crc_nigerian_2020  s_PK_crc_126_T           36.0         True
# 7854  crc_nigerian_2020  s_PK_crc_127_T           34.0         True
# 7856  crc_nigerian_2020  s_PK_crc_132_T           36.0         True
# 7860  crc_nigerian_2020  s_PK_crc_136_T           39.0         True
#
# [581 rows x 4 columns]
